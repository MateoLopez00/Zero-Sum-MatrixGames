# %% [markdown]
# # Section 4 Extension: Noise Robustness
#
# This notebook tests how Gaussian bandit feedback noise affects Section 4. Each round observes only the played cell reward `r_t = clip(A[i_t, j_t] + sigma * Gaussian, 0, 1)`. The comparison uses **UCB**, **EXP3**, and the official **OurAlg** (the bandit implementation from the paper).

# %%
from importlib import reload

from IPython.display import Image, display

import section4_noise_robustness

section4_noise_robustness = reload(section4_noise_robustness)
run_and_plot = section4_noise_robustness.run_and_plot
run_convergence_and_plot = section4_noise_robustness.run_convergence_and_plot

# %% [markdown]
# ## Run Experiment
#
# Use `quick` for a fast check. Use `medium` or `paper-lite` for report-quality runs.

# %%
preset = "paper-lite"  # options: "quick", "medium", "paper-lite"
seed = 42

bundle, regret_path, payoff_path = run_and_plot(preset, seed=seed)
metadata = bundle["metadata"]
results = bundle["results"]
metadata
# Out:
# -- Adversary 1 ------------------------------------------------
#   sigma=0.00  UCB: R=    3.22, P=0.2222  EXP3: R=  109.57, P=0.2211  OurAlg: R=   34.83, P=0.2219
#   sigma=0.05  UCB: R=    4.03, P=0.2222  EXP3: R=  114.09, P=0.2211  OurAlg: R=   39.14, P=0.2218
#   sigma=0.10  UCB: R=    4.43, P=0.2222  EXP3: R=  120.02, P=0.2210  OurAlg: R=   45.81, P=0.2218
#   sigma=0.20  UCB: R=    6.01, P=0.2222  EXP3: R=  131.37, P=0.2209  OurAlg: R=   63.22, P=0.2216
#   sigma=0.30  UCB: R=    7.53, P=0.2221  EXP3: R=  141.27, P=0.2208  OurAlg: R=   77.90, P=0.2214
#
# -- Adversary 2 ------------------------------------------------
#   sigma=0.00  UCB: R=   28.38, P=0.2219  EXP3: R=  110.60, P=0.2211  OurAlg: R=   39.41, P=0.2218
#   sigma=0.05  UCB: R=   37.25, P=0.2218  EXP3: R=  113.62, P=0.2211  OurAlg: R=   44.39, P=0.2218
#   sigma=0.10  UCB: R=   46.76, P=0.2218  EXP3: R=  119.29, P=0.2210  OurAlg: R=   50.92, P=0.2217
#   sigma=0.20  UCB: R=   59.58, P=0.2216  EXP3: R=  133.62, P=0.2209  OurAlg: R=   75.23, P=0.2215
#   sigma=0.30  UCB: R=   59.01, P=0.2216  EXP3: R=  140.74, P=0.2208  OurAlg: R=   86.07, P=0.2214
#
# -- Adversary 3 ------------------------------------------------
#   sigma=0.00  UCB: R=  102.19, P=0.2212  EXP3: R=  108.79, P=0.2211  OurAlg: R=    1.20, P=0.2222
#   sigma=0.05  UCB: R=  201.14, P=0.2202  EXP3: R=  232.25, P=0.2199  OurAlg: R=    1.32, P=0.2222
#   sigma=0.10  UCB: R=  365.63, P=0.2186  EXP3: R=  298.35, P=0.2192  OurAlg: R=    1.67, P=0.2222
#   sigma=0.20  UCB: R=  754.92, P=0.2147  EXP3: R=  758.62, P=0.2146  OurAlg: R=    2.84, P=0.2222
#   sigma=0.30  UCB: R=  778.26, P=0.2144  EXP3: R=  703.05, P=0.2152  OurAlg: R=    2.86, P=0.2222
# Figure saved -> D:\Users\Mateo\Personal\_Seminar_RL\Zero-Sum-MatrixGames\Extensions\Extension_Noise_Robustness_Bandit_feedback\plots\section4_noise_regret_paper-lite.png
# Figure saved -> D:\Users\Mateo\Personal\_Seminar_RL\Zero-Sum-MatrixGames\Extensions\Extension_Noise_Robustness_Bandit_feedback\plots\section4_noise_payoff_paper-lite.png
#
# Final sigma summary
# ------------------------------------------------------------------------
#
# Adversary 1, sigma=0.3
#            Algorithm    NashRegret   AvgPayoff
#                  UCB          7.53      0.2221
#                 EXP3        141.27      0.2208
#               OurAlg         77.90      0.2214
#
# Adversary 2, sigma=0.3
#            Algorithm    NashRegret   AvgPayoff
#                  UCB         59.01      0.2216
#                 EXP3        140.74      0.2208
#               OurAlg         86.07      0.2214
#
# Adversary 3, sigma=0.3
#            Algorithm    NashRegret   AvgPayoff
#                  UCB        778.26      0.2144
#                 EXP3        703.05      0.2152
#               OurAlg          2.86      0.2222
# {'preset': 'paper-lite',
#  'sigma_values': [0.0, 0.05, 0.1, 0.2, 0.3],
#  'n_runs': 32,
#  'horizon': 100000}

# %% [markdown]
# ## Generated Plots

# %%
display(Image(filename=str(regret_path)))
display(Image(filename=str(payoff_path)))

# %% [markdown]
# ## Convergence under high noise
#
# The previous plots summarize final performance as `sigma` changes. The convergence figure below fixes `sigma = 0.3` and shows cumulative Nash regret over time, with one panel for each Section 4 adversary. Curves are averaged over the same number of runs as the selected preset, with shaded one-standard-deviation bands.

# %%
_, convergence_paths = run_convergence_and_plot(
    preset=preset,
    seed=seed,
)
for path in convergence_paths:
    display(Image(filename=str(path)))
# Out:
# Section 4 convergence
# sigma=0.1, T=100000, n_runs=32
#
# -- Adversary 1 ------------------------------------------------
# UCB: final R=4.43
# EXP3: final R=120.02
# OurAlg: final R=45.81
#
# -- Adversary 2 ------------------------------------------------
# UCB: final R=46.76
# EXP3: final R=119.29
# OurAlg: final R=50.92
#
# -- Adversary 3 ------------------------------------------------
# UCB: final R=365.63
# EXP3: final R=298.35
# OurAlg: final R=1.67
# Figure saved -> D:\Users\Mateo\Personal\_Seminar_RL\Zero-Sum-MatrixGames\Extensions\Extension_Noise_Robustness_Bandit_feedback\plots\section4_convergence_paper-lite_sigma0p1.png
#
# Section 4 convergence
# sigma=0.2, T=100000, n_runs=32
#
# -- Adversary 1 ------------------------------------------------
# UCB: final R=6.01
# EXP3: final R=131.37
# OurAlg: final R=63.22
#
# -- Adversary 2 ------------------------------------------------
# UCB: final R=59.58
# EXP3: final R=133.62
# OurAlg: final R=75.23
#
# -- Adversary 3 ------------------------------------------------
# UCB: final R=754.92
# EXP3: final R=758.62
# OurAlg: final R=2.84
# Figure saved -> D:\Users\Mateo\Personal\_Seminar_RL\Zero-Sum-MatrixGames\Extensions\Extension_Noise_Robustness_Bandit_feedback\plots\section4_convergence_paper-lite_sigma0p2.png
#
# Section 4 convergence
# sigma=0.3, T=100000, n_runs=32
#
# -- Adversary 1 ------------------------------------------------
# UCB: final R=7.53
# EXP3: final R=141.27
# OurAlg: final R=77.90
#
# -- Adversary 2 ------------------------------------------------
# UCB: final R=59.01
# EXP3: final R=140.74
# OurAlg: final R=86.07
#
# -- Adversary 3 ------------------------------------------------
# UCB: final R=778.26
# EXP3: final R=703.05
# OurAlg: final R=2.86
# Figure saved -> D:\Users\Mateo\Personal\_Seminar_RL\Zero-Sum-MatrixGames\Extensions\Extension_Noise_Robustness_Bandit_feedback\plots\section4_convergence_paper-lite_sigma0p3.png

# %%
# Convergence figures are displayed in the previous cell (one PNG per sigma).

# %% [markdown]
# ## Interpretation
#
# Section 4 uses bandit feedback, so the learner sees only one noisy payoff per round. The expected behavior is stronger sensitivity to increasing `sigma` than in Section 3, especially for algorithms that need accurate estimates of individual matrix entries.
#
# Watch how **OurAlg** compares to **UCB** and **EXP3** across noise levels and adversaries; convergence plots at multiple `sigma` values summarize cumulative regret over time.
