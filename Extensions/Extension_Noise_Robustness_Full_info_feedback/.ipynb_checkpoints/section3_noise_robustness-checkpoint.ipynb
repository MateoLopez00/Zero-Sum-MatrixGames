# %% [markdown]
# # Section 3 Extension: Noise Robustness
#
# This notebook tests how Gaussian full-information feedback noise affects Section 3. Each round observes the full matrix sample `A_t = clip(A + sigma * Gaussian, 0, 1)`. The comparison keeps Nash, Hedge, and the official Our-Algo unchanged, and adds `Our-Algo-NoiseAware`, a sigma-adaptive variant that uses a larger update threshold as feedback noise increases.

# %%
from importlib import util
from pathlib import Path

from IPython.display import Image, display

MODULE_PATH = Path("section3_noise_robustness.py")
if not MODULE_PATH.exists():
    MODULE_PATH = Path("Extensions/Extension_Noise_Robustness_Full_info_feedback/section3_noise_robustness.py")
MODULE_PATH = MODULE_PATH.resolve()

spec = util.spec_from_file_location("section3_noise_robustness_local", MODULE_PATH)
section3_noise_robustness = util.module_from_spec(spec)
assert spec.loader is not None
spec.loader.exec_module(section3_noise_robustness)

run_and_plot = section3_noise_robustness.run_and_plot
run_convergence_and_plot = section3_noise_robustness.run_convergence_and_plot
plot_section3_noiseaware_improvement = section3_noise_robustness.plot_section3_noiseaware_improvement
print_summary = section3_noise_robustness.print_summary

print("Loaded:", MODULE_PATH)
print("Algorithms:", ", ".join(section3_noise_robustness.ALGORITHM_ORDER))
assert "Our-Algo-NoiseAware" in section3_noise_robustness.ALGORITHM_ORDER
# Out:
# Loaded: D:\Users\Mateo\Personal\_Seminar_RL\Zero-Sum-MatrixGames\Extensions\Extension_Noise_Robustness_Full_info_feedback\section3_noise_robustness.py
# Algorithms: Nash, Hedge, Our-Algo, Our-Algo-NoiseAware

# %% [markdown]
# ## Run Experiment
#
# Use `quick` for a fast check. Use `medium` or `paper-lite` for report-quality runs.

# %%
preset = "paper-lite"  # options: "quick", "medium", "paper-lite"
seed = 7

bundle, regret_path, payoff_path = run_and_plot(preset, seed=seed)
metadata = bundle["metadata"]
results = bundle["results"]

for n, algorithm_results in results.items():
    assert "Our-Algo-NoiseAware" in algorithm_results, f"Noise-aware results missing for n={n}"

metadata
# Out:
# -- n=10 -------------------------------------------------------
#   sigma=0.00  Nash: R=    0.01, P=0.0492  Hedge: R=    6.97, P=0.0491  Our-Algo: R=    4.58, P=0.0492  Our-Algo-NoiseAware: R=    4.58, P=0.0492
#   sigma=0.10  Nash: R=   10.09, P=0.0491  Hedge: R=    7.67, P=0.0491  Our-Algo: R=    4.92, P=0.0492  Our-Algo-NoiseAware: R=    4.87, P=0.0492
#   sigma=0.20  Nash: R=   22.91, P=0.0489  Hedge: R=   10.75, P=0.0491  Our-Algo: R=    5.33, P=0.0491  Our-Algo-NoiseAware: R=    5.45, P=0.0491
#   sigma=0.30  Nash: R=  113.08, P=0.0480  Hedge: R=   16.30, P=0.0490  Our-Algo: R=    8.54, P=0.0491  Our-Algo-NoiseAware: R=    8.25, P=0.0491
#
# -- n=20 -------------------------------------------------------
#   sigma=0.00  Nash: R=    0.00, P=0.0246  Hedge: R=    4.53, P=0.0246  Our-Algo: R=    4.87, P=0.0246  Our-Algo-NoiseAware: R=    4.87, P=0.0246
#   sigma=0.10  Nash: R=    5.80, P=0.0246  Hedge: R=    5.47, P=0.0246  Our-Algo: R=    4.93, P=0.0246  Our-Algo-NoiseAware: R=    4.85, P=0.0246
#   sigma=0.20  Nash: R=   14.96, P=0.0245  Hedge: R=    8.93, P=0.0245  Our-Algo: R=    5.05, P=0.0246  Our-Algo-NoiseAware: R=    5.03, P=0.0246
#   sigma=0.30  Nash: R=   58.66, P=0.0240  Hedge: R=   15.48, P=0.0245  Our-Algo: R=    6.36, P=0.0246  Our-Algo-NoiseAware: R=    6.08, P=0.0246
#
# -- n=50 -------------------------------------------------------
#   sigma=0.00  Nash: R=    0.00, P=0.0099  Hedge: R=    2.62, P=0.0098  Our-Algo: R=    5.05, P=0.0098  Our-Algo-NoiseAware: R=    5.05, P=0.0098
#   sigma=0.10  Nash: R=    3.01, P=0.0098  Hedge: R=    3.81, P=0.0098  Our-Algo: R=    4.89, P=0.0098  Our-Algo-NoiseAware: R=    4.79, P=0.0098
#   sigma=0.20  Nash: R=    7.41, P=0.0098  Hedge: R=    7.78, P=0.0098  Our-Algo: R=    4.73, P=0.0098  Our-Algo-NoiseAware: R=    4.60, P=0.0098
#   sigma=0.30  Nash: R=   24.41, P=0.0096  Hedge: R=   15.33, P=0.0097  Our-Algo: R=    5.02, P=0.0098  Our-Algo-NoiseAware: R=    4.78, P=0.0098
#
# -- n=100 -------------------------------------------------------
#   sigma=0.00  Nash: R=    0.00, P=0.0049  Hedge: R=    1.84, P=0.0049  Our-Algo: R=    5.09, P=0.0049  Our-Algo-NoiseAware: R=    5.09, P=0.0049
#   sigma=0.10  Nash: R=    1.68, P=0.0049  Hedge: R=    3.14, P=0.0049  Our-Algo: R=    4.84, P=0.0049  Our-Algo-NoiseAware: R=    4.75, P=0.0049
#   sigma=0.20  Nash: R=    4.35, P=0.0049  Hedge: R=    7.47, P=0.0049  Our-Algo: R=    4.64, P=0.0049  Our-Algo-NoiseAware: R=    4.47, P=0.0049
#   sigma=0.30  Nash: R=   12.99, P=0.0048  Hedge: R=   15.75, P=0.0048  Our-Algo: R=    4.58, P=0.0049  Our-Algo-NoiseAware: R=    4.30, P=0.0049
# Figure saved -> D:\Users\Mateo\Personal\_Seminar_RL\Zero-Sum-MatrixGames\Extensions\Extension_Noise_Robustness_Full_info_feedback\plots\section3_noise_regret_paper-lite.png
# Figure saved -> D:\Users\Mateo\Personal\_Seminar_RL\Zero-Sum-MatrixGames\Extensions\Extension_Noise_Robustness_Full_info_feedback\plots\section3_noise_payoff_paper-lite.png
#
# Final sigma summary
# ------------------------------------------------------------------------
#
# n=10, sigma=0.3
#            Algorithm    NashRegret   AvgPayoff
#                 Nash        113.08      0.0480
#                Hedge         16.30      0.0490
#             Our-Algo          8.54      0.0491
#  Our-Algo-NoiseAware          8.25      0.0491
#
# n=20, sigma=0.3
#            Algorithm    NashRegret   AvgPayoff
#                 Nash         58.66      0.0240
#                Hedge         15.48      0.0245
#             Our-Algo          6.36      0.0246
#  Our-Algo-NoiseAware          6.08      0.0246
#
# n=50, sigma=0.3
#            Algorithm    NashRegret   AvgPayoff
#                 Nash         24.41      0.0096
#                Hedge         15.33      0.0097
#             Our-Algo          5.02      0.0098
#  Our-Algo-NoiseAware          4.78      0.0098
#
# n=100, sigma=0.3
#            Algorithm    NashRegret   AvgPayoff
#                 Nash         12.99      0.0048
#                Hedge         15.75      0.0048
#             Our-Algo          4.58      0.0049
#  Our-Algo-NoiseAware          4.30      0.0049
# {'preset': 'paper-lite',
#  'sigma_values': [0.0, 0.1, 0.2, 0.3],
#  'n_runs': 12,
#  'horizon': 100000}

# %% [markdown]
# ## Generated Plots

# %% [markdown]
# ## Relative improvement at high noise
#
# The regret and payoff curves overlap because the original and noise-aware algorithms are close on the plot scale. The bar chart below isolates the comparison at `sigma = 0.3` and shows the percentage regret reduction of `Our-Algo-NoiseAware` relative to `Our-Algo` for each matrix size.

# %%
improvement_path = MODULE_PATH.parent / "plots" / f"section3_noiseaware_improvement_{preset}_sigma0p3.png"
plot_section3_noiseaware_improvement(
    results,
    metadata["sigma_values"],
    improvement_path,
    sigma=0.3,
)
display(Image(filename=str(improvement_path)))
# Out:
# Figure saved -> D:\Users\Mateo\Personal\_Seminar_RL\Zero-Sum-MatrixGames\Extensions\Extension_Noise_Robustness_Full_info_feedback\plots\section3_noiseaware_improvement_paper-lite_sigma0p3.png

# %%
display(Image(filename=str(regret_path)))
display(Image(filename=str(payoff_path)))

# %% [markdown]
# ## Convergence under high noise
#
# The previous plots summarize final performance as `sigma` changes. The convergence plot below fixes a representative high-noise setting, `n = 20` and `sigma = 0.3`, and shows how cumulative Nash regret evolves over time. Curves are averaged over the same number of runs as the selected preset, with shaded one-standard-deviation bands.

# %%
_, convergence_paths = run_convergence_and_plot(
    preset=preset,
    seed=seed,
    n=100,
)
for path in convergence_paths:
    display(Image(filename=str(path)))
# Out:
# Section 3 convergence
# n=100, sigma=0.1, T=100000, n_runs=12
# Nash: final R=1.68
# Hedge: final R=3.14
# Our-Algo: final R=4.84
# Our-Algo-NoiseAware: final R=4.75
# Figure saved -> D:\Users\Mateo\Personal\_Seminar_RL\Zero-Sum-MatrixGames\Extensions\Extension_Noise_Robustness_Full_info_feedback\plots\section3_convergence_paper-lite_n100_sigma0p1.png
#
# Section 3 convergence
# n=100, sigma=0.2, T=100000, n_runs=12
# Nash: final R=4.35
# Hedge: final R=7.47
# Our-Algo: final R=4.64
# Our-Algo-NoiseAware: final R=4.47
# Figure saved -> D:\Users\Mateo\Personal\_Seminar_RL\Zero-Sum-MatrixGames\Extensions\Extension_Noise_Robustness_Full_info_feedback\plots\section3_convergence_paper-lite_n100_sigma0p2.png
#
# Section 3 convergence
# n=100, sigma=0.3, T=100000, n_runs=12
# Nash: final R=12.99
# Hedge: final R=15.75
# Our-Algo: final R=4.58
# Our-Algo-NoiseAware: final R=4.30
# Figure saved -> D:\Users\Mateo\Personal\_Seminar_RL\Zero-Sum-MatrixGames\Extensions\Extension_Noise_Robustness_Full_info_feedback\plots\section3_convergence_paper-lite_n100_sigma0p3.png

# %%
# Convergence figures are displayed in the previous cell (one PNG per sigma).

# %% [markdown]
# ## Interpretation
#
# Section 3 uses full-information feedback, so the learner sees much more data each round than in the bandit setting. The expected behavior is a gradual degradation as `sigma` increases, rather than a sudden collapse.
#
# The new comparison to watch is `Our-Algo` versus `Our-Algo-NoiseAware`. If the noise-aware threshold helps, the red noise-aware curve should remain flatter in regret and/or closer to the game value in average payoff at larger `sigma`.
